# %%
from PIL import Image
import pytesseract
from matplotlib import pyplot as plt
import numpy as np

# %%
x = Image.open('./cars/positive/resize_step_2_019.jpg')
plt.imshow(x)

# %%
pytesseract.image_to_string(x,lang='tha')
# Out:
# ''

# %%
y = np.asarray(x)

# %%
pytesseract.image_to_string(y,lang='tha')
# Out:
# 'กย 2224\n\nเชียงราย 7'

# %%
plt.imshow(y)

# %%
y
# Out:
# array([[[145, 141, 129],
#         [151, 147, 135],
#         [142, 138, 126],
#         ...,
#         [ 93,  85,  72],
#         [112, 104,  91],
#         [134, 126, 113]],
#
#        [[117, 113, 101],
#         [114, 110,  98],
#         [110, 106,  94],
#         ...,
#         [115, 107,  94],
#         [128, 120, 107],
#         [141, 135, 121]],
#
#        [[ 98,  94,  82],
#         [104, 100,  88],
#         [100,  96,  84],
#         ...,
#         [133, 125, 114],
#         [139, 133, 121],
#         [142, 136, 124]],
#
#        ...,
#
#        [[118, 114, 105],
#         [129, 125, 116],
#         [187, 183, 174],
#         ...,
#         [140, 134, 122],
#         [140, 134, 120],
#         [142, 134, 121]],
#
#        [[148, 141, 133],
#         [119, 115, 106],
#         [145, 141, 132],
#         ...,
#         [145, 139, 125],
#         [144, 138, 124],
#         [144, 136, 123]],
#
#        [[160, 153, 143],
#         [140, 133, 125],
#         [147, 143, 134],
# ...
